# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/The Lannister Data Chronicles_ Decrypting Diabetes.csv")

# %%
data. describe()
# Out:
#         Diabetes_012         HighBP       HighChol      CholCheck  \
# count  206786.000000  206786.000000  206786.000000  206786.000000
# mean        0.297375       0.431228       0.425198       0.963223
# std         0.698457       0.495249       0.494374       0.188215
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       1.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         0.000000       1.000000       1.000000       1.000000
# max         2.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke  HeartDiseaseorAttack  \
# count  206786.000000  206786.000000  206786.000000         206786.000000
# mean       28.419530       0.450848       0.041033              0.095035
# std         6.709822       0.497579       0.198366              0.293265
# min        12.000000       0.000000       0.000000              0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206786 entries, 0 to 206785
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          206786 non-null  int64
#  1   HighBP                206786 non-null  int64
#  2   HighChol              206786 non-null  int64
#  3   CholCheck             206786 non-null  int64
#  4   BMI                   206786 non-null  int64
#  5   Smoker                206786 non-null  int64
#  6   Stroke                206786 non-null  int64
#  7   HeartDiseaseorAttack  206786 non-null  int64
#  8   PhysActivity          206786 non-null  int64
#  9   Fruits                206786 non-null  int64
#  10  Veggies               206786 non-null  int64
#  11  HvyAlcoholConsump     206786 non-null  int64
#  12  AnyHealthcare         206786 non-null  int64
#  13  NoDocbcCost           206786 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# Diabetes_012            0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     1
# Education               1
# Income                  1
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 17845

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Diabetes_012',data=data)
plt.show()

# %%
plt.figure(figsize=(12,12))
for i,col in enumerate(['Diabetes_012','HighBP','HighChol','CholCheck','BMI','Smoker','Stroke','HeartDiseaseorAttack','PhysActivity','Fruits','Veggies','HvyAlcoholConsump','AnyHealthcare','NoDocbcCost','GenHlth','MentHlth','PhysHlth','DiffWalk','Sex','Age','Education','Income']):
  plt.subplot(5,5,i+1)
  sns.boxplot(x=col,data=data)
plt.show()

# %%
plt.figure(figsize=(12,12))
for i,col in enumerate(['Diabetes_012','HighBP','HighChol','CholCheck','BMI','Smoker','Stroke','HeartDiseaseorAttack','PhysActivity','Fruits','Veggies','HvyAlcoholConsump','AnyHealthcare','NoDocbcCost','GenHlth','MentHlth','PhysHlth','DiffWalk','Sex','Age','Education','Income']):
  plt.subplot(5,5,i+1)
  sns.histplot(x=col,data=data,kde=True)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data.corr(),vmin= -1.0, center = 0, cmap = 'RdBu_r',annot=True)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import joblib

# Load the dataset
file_path = '/content/The Lannister Data Chronicles_ Decrypting Diabetes.csv'
data = pd.read_csv(file_path)

# Features (X) and target (y)
X = data.drop(columns=['Diabetes_012'])
y = data['Diabetes_012']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = rf_model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", classification_rep)

# Save the model and scaler
joblib.dump(rf_model, 'rf_model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# Accuracy: 0.8421370755807842
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91     64180
#            1       0.00      0.00      0.00      1425
#            2       0.48      0.20      0.28     10499
#
#     accuracy                           0.84     76104
#    macro avg       0.45      0.39      0.40     76104
# weighted avg       0.80      0.84      0.81     76104
# ['scaler.pkl']

# %%
import joblib
import numpy as np

# Load the model and scaler
rf_model = joblib.load('rf_model.pkl')
scaler = joblib.load('scaler.pkl')

# Function to take input from console and make a prediction
def predict_from_console():
    print("Enter the following details:")

    # Collecting user input for each feature
    HighBP = float(input("HighBP (0 or 1): "))
    HighChol = float(input("HighChol (0 or 1): "))
    CholCheck = float(input("CholCheck (0 or 1): "))
    BMI = float(input("BMI: "))
    Smoker = float(input("Smoker (0 or 1): "))
    Stroke = float(input("Stroke (0 or 1): "))
    HeartDiseaseorAttack = float(input("HeartDiseaseorAttack (0 or 1): "))
    PhysActivity = float(input("PhysActivity (0 or 1): "))
    Fruits = float(input("Fruits (0 or 1): "))
    Veggies = float(input("Veggies (0 or 1): "))
    HvyAlcoholConsump = float(input("HvyAlcoholConsump (0 or 1): "))
    AnyHealthcare = float(input("AnyHealthcare (0 or 1): "))
    NoDocbcCost = float(input("NoDocbcCost (0 or 1): "))
    GenHlth = float(input("GenHlth (scale 1-5): "))
    MentHlth = float(input("MentHlth: "))
    PhysHlth = float(input("PhysHlth: "))
    DiffWalk = float(input("DiffWalk (0 or 1): "))
    Sex = float(input("Sex (0 or 1): "))
    Age = float(input("Age (1-13): "))
    Education = float(input("Education (1-6): "))
    Income = float(input("Income (1-8): "))

    # Creating a feature array
    features = np.array([[HighBP, HighChol, CholCheck, BMI, Smoker, Stroke, HeartDiseaseorAttack,
                          PhysActivity, Fruits, Veggies, HvyAlcoholConsump, AnyHealthcare, NoDocbcCost,
                          GenHlth, MentHlth, PhysHlth, DiffWalk, Sex, Age, Education, Income]])

    # Scaling the features
    scaled_features = scaler.transform(features)

    # Making a prediction
    prediction = rf_model.predict(scaled_features)
    output = int(prediction[0])

    # Output the result
    print(f"Diabetes Prediction: {output}")

# Run the prediction function
if __name__ == "__main__":
    predict_from_console()
# Out:
# Enter the following details:
# HighBP (0 or 1): 0
# HighChol (0 or 1): 1
# CholCheck (0 or 1): 1
# BMI: 23
# Smoker (0 or 1): 0
# Stroke (0 or 1): 0
# HeartDiseaseorAttack (0 or 1): 0
# PhysActivity (0 or 1): 0
# Fruits (0 or 1): 1
# Veggies (0 or 1): 1
# HvyAlcoholConsump (0 or 1): 0
# AnyHealthcare (0 or 1): 1
# NoDocbcCost (0 or 1): 0
# GenHlth (scale 1-5): 2
# MentHlth: 2
# PhysHlth: 1
# DiffWalk (0 or 1): 0
# Sex (0 or 1): 0
# Age (1-13): 13
# Education (1-6): 4
# Income (1-8): 3
# Diabetes Prediction: 0
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
